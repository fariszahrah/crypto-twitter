# %%
import pandas as pd
import collect 
import numpy as np
from importlib import reload
import matplotlib.pyplot as plt
import cluster

# %%
reload(collect)
# Out:
# <module 'collect' from '/Users/fariszahrah/Documents/IIT/CS579/fariszahrah/a4/collect.py'>

# %%
users = pd.read_pickle('./data.pkl')

# %%
tweets = pd.read_pickle('./tweets.pkl')
tweets.shape
# Out:
# (8299, 29)

# %%
 graph = nx.read_gpickle('./graph.gpickle')

# %%
graph.edges(23137860)
# Out:
# EdgeDataView([(23137860, 12), (23137860, 657863), (23137860, 2730791), (23137860, 5750512), (23137860, 6213582), (23137860, 14444941), (23137860, 15935591), (23137860, 28582680), (23137860, 35749949), (23137860, 50393960), (23137860, 101580574), (23137860, 176758255), (23137860, 571202103), (23137860, 1051053836), (23137860, 3719087053), (23137860, 902839045356744704)])

# %%
import community
import pickle

# %%
part = community.best_partition(graph)
values = [part.get(node) for node in graph.nodes()]
nx.draw_spring(graph, cmap = plt.get_cmap('jet'), node_color = values, node_size=30, with_labels=False)
plt.savefig('Network.png', pad_inches=4)

# %%
s=0
for i in c:
    s += c[i]/len(c)

# %%
t2_df = pd.read_pickle('./main_user_tweets.pkl')

# %%
t2_df.head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Thu Apr 25 05:04:08 +0000 2019
# 1         None        None  Thu Apr 25 05:03:40 +0000 2019
# 2         None        None  Thu Apr 25 04:54:21 +0000 2019
# 3         None        None  Wed Apr 24 17:28:04 +0000 2019
# 4         None        None  Wed Apr 24 17:05:02 +0000 2019
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
#
#    favorite_count  favorited   geo                   id               id_str  \
# 0               0      False  None  1121278698425069568  1121278698425069568
# 1               8      False  None  1121278578937815040  1121278578937815040
# 2               0      False  None  1121276235236220928  1121276235236220928
# 3               6      False  None  1121103525843480577  1121103525843480577
# 4              22      False  None  1121097728455512070  1121097728455512070
#
#                      ...                    quoted_status  quoted_status_id  \
# 0                    ...                              NaN               NaN
# 1                    ...                              NaN               NaN
# 2                    ...                              NaN               NaN
# 3                    ...                              NaN               NaN
# 4                    ...                              NaN               NaN
#
#   quoted_status_id_str  retweet_count retweeted  \
# 0                  NaN             76     False
# 1                  NaN              0     False
# 2                  NaN             70     False
# 3                  NaN              0     False
# 4                  NaN              0     False
#
#                                     retweeted_status  \
# 0  {'created_at': 'Wed Apr 24 20:07:40 +0000 2019...
# 1                                                NaN
# 2  {'created_at': 'Wed Apr 24 10:43:07 +0000 2019...
# 3                                                NaN
# 4                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="http://twitter.com" rel="nofollow">Tw...
# 3  <a href="https://mobile.twitter.com" rel="nofo...
# 4  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                                 text truncated  \
# 0  RT @dannyryan: v0.6.0 — Spring Cleaning — rele...     False
# 1  @drakefjustin NOT simple!\n\nThough compared t...     False
# 2  RT @drakefjustin: Filecoin and Ethereum 2.0 co...     False
# 3  @bitcoinization @Maxahoy Just use buttcoin's. ...     False
# 4                     @bitcoinization July-Aug 2014.     False
#
#                                        user
# 0  {'id': 295218901, 'id_str': '295218901'}
# 1  {'id': 295218901, 'id_str': '295218901'}
# 2  {'id': 295218901, 'id_str': '295218901'}
# 3  {'id': 295218901, 'id_str': '295218901'}
# 4  {'id': 295218901, 'id_str': '295218901'}
#
# [5 rows x 29 columns]

# %%
with open('partition.pickle', 'rb') as handle:
    f = pickle.load(handle)

# %% [markdown]
# <b>NOW WE TACKLE CLASSIFICATION</b>
#
#
# first i will classify a sample of the tweets i collected, and label them

# %%
sample = tweets.sample(frac=1/20,random_state=3)

# %%
sample.to_excel('train_tweets.xlsx')

# %% [markdown]
# Trading => 0
# Technology => 1
# N/A => 2

# %%
train = pd.read_excel('train_tweets.xlsx')
target = train['Target']
train.drop(['Target','contributors','favorited','id','id_str','retweeted','coordinates','created_at','geo'], inplace=True, axis=1)

# %%
train['text_f']= [0 for i in range(train.shape[0])]

# %%
terms = set()
for row in range(train.shape[0]):
    terms |= set(nltk.word_tokenize(train.iloc[row]['text']))
    #print(train.iloc[row]['text_f'] train.iloc[row]['text'])

# %%
t = [i for i in train['text'].tolist()]
t1 = [i for i in t2_df['text'].tolist()]

# %%
t_sum = t + t1
len(t_sum), len(t), len(t1)
# Out:
# (6778, 415, 6363)

# %%
from sklearn.feature_extraction.text import *
tfidf_vectorizer = TfidfVectorizer(min_df=2)
X_tfidf = tfidf_vectorizer.fit_transform(t_sum)

# %%
X_tfidf.shape
# Out:
# (6778, 6135)

# %%
train_df = pd.DataFrame(X_train_tfidf.todense()).iloc[:415]
test_df  = pd.DataFrame(X_train_tfidf.todense()).iloc[416:]

# %%
from sklearn.ensemble import RandomForestClassifier  
import sklearn as sk 
import re
import nltk

# %%
RF = RandomForestClassifier(n_estimators=1000, max_depth=30, random_state=0).fit(train_df, target)  
predictions = RF.predict(test_df)

# %%
predictions = RF.predict(test_df)  
predictions = predictions.tolist()
zero = 0
one = 0
two = 0
for i in predictions:
    if i == 0:
        zero +=1
    elif i ==1:
        one +=1
    elif i == 2:
        two +=1
        
print(zero,one,two)
# Out:
# 915 482 4965

# %%
from collections import Counter
c = Counter(predictions)

# %%
for i in c:
    print(i, c[i])
# Out:
# 2 4965
# 1 482
# 0 915

# %%
dict(c)
# Out:
# {2: 4965, 1: 482, 0: 915}
